# %% [markdown]
# <a href="https://colab.research.google.com/github/aguchhait-stack/Timeseries/blob/main/Times_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import datetime as dt
color_pal=sns.color_palette()

# %%
df = pd.read_csv(r'/content/drive/MyDrive/AEP_hourly.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
df.nunique()
# Out:
# Datetime    121269
# AEP_MW       12643
# dtype: int64

# %%
df['Datetime']=pd.to_datetime(df['Datetime'])

# %%
df.set_index("Datetime",inplace=True)

# %%
df.head()
# Out:
#                       AEP_MW
# Datetime
# 2004-12-31 01:00:00  13478.0
# 2004-12-31 02:00:00  12865.0
# 2004-12-31 03:00:00  12577.0
# 2004-12-31 04:00:00  12517.0
# 2004-12-31 05:00:00  12670.0

# %%
df.plot(style='.',color=color_pal[4],title='AEP',figsize=(30,15))
# Out:
# <Axes: title={'center': 'AEP'}, xlabel='Datetime'>

# %%
train =df.loc[df.index<'01-01-2015']
test= df[df.index>='01-01-2015']

# %%
train.size
# Out:
# 89833

# %%
test.size
# Out:
# 31440

# %% [markdown]
# # New Section

# %%
# prompt: subplot with two dataframe

fig, ax = plt.subplots(figsize=(30,15))
train.plot(ax=ax, label='Training Set', color=color_pal[4])
test.plot(ax=ax, label='Test Set', color=color_pal[2])
ax.axvline('01-01-2015',color='black',linestyle='-')
ax.legend(['Training','Testing'])
ax.set_title('AEP')
plt.show()
